# %%
import os
os.environ["OMP_NUM_THREADS"] = "1"  # Prevent memory leak on Windows with MKL

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster

# %%
# 1. Load and preprocess the dataset
iris = load_iris()
df = pd.DataFrame(iris.data, columns=iris.feature_names)  # Create DataFrame
feature_names = iris.feature_names

# %%
# Standardize the dataset
scaler = StandardScaler()
df_scaled = pd.DataFrame(scaler.fit_transform(df), columns=feature_names)

# %%
# Visualize KMeans Clustering
plt.figure(figsize=(10, 5))
plt.scatter(df_scaled.iloc[:, 0], df_scaled.iloc[:, 1], c=kmeans_labels, cmap='viridis', s=50)
plt.title("KMeans Clustering")
plt.xlabel(feature_names[0])
plt.ylabel(feature_names[1])
plt.show()

# %%
# 2B. Hierarchical Clustering
# Compute the linkage matrix
linkage_matrix = linkage(df_scaled, method='ward')

# %%
# Visualize the dendrogram
plt.figure(figsize=(10, 5))
dendrogram(linkage_matrix, truncate_mode='lastp', p=12)
plt.title("Hierarchical Clustering Dendrogram")
plt.show()

# %%
# Apply hierarchical clustering to form 3 clusters
hierarchical_labels = fcluster(linkage_matrix, t=3, criterion='maxclust')

# %%
# Visualize Hierarchical Clustering
plt.figure(figsize=(10, 5))
plt.scatter(df_scaled.iloc[:, 0], df_scaled.iloc[:, 1], c=hierarchical_labels, cmap='viridis', s=50)
plt.title("Hierarchical Clustering")
plt.xlabel(feature_names[0])
plt.ylabel(feature_names[1])
plt.show()
